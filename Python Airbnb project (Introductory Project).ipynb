# %%
import pandas as pd
import os

df = pd.read_csv("C:\\Users\\ivano\\OneDrive\\Documents\\KEDGE\\MSC DATA\\Courses\\\Python bootcamp\\Python_Airbnb_project\\Denver dataset\\Description.csv")

# %%
df.head(5)
# Out:
#      id                                         name  \
# 0   360  LoHi Secret garden at the Chickadee Cottage
# 1   590            Comfortable  - and a great value!
# 2   592                                      private
# 3  1940             Baker Studio Close to EVERYTHING
# 4  2086                           Garden Level Condo
#
#                                              summary  \
# 0  Come enjoy our oasis is the city and stay at o...
# 1  Large guest room in my home, where I also live...
# 2  This room is in the basement.  It does not hav...
# 3  Great place for a few nights or months! Signif...
# 4  A furnished, garden level, one bedroom/one bat...
#
#                                                space  \
# 0  Chickadee Cottage is the largest of our guest ...
# 1  I have been enjoying welcoming many wonderful ...
# 2  This is a basement room.  You can sometimes he...
# 3  This newly built, highly functional studio is ...
# ...

# %%
import pandas as pd
import os

df_size = pd.read_csv("C:\\Users\\ivano\\OneDrive\\Documents\\KEDGE\\MSC DATA\\Courses\\\Python bootcamp\\Python_Airbnb_project\\Denver dataset\\Size.csv")

# %%
df_size.head()
# Out:
#      id property_type        room_type  accommodates  bathrooms  bedrooms  \
# 0   360    Guesthouse  Entire home/apt             4        1.0       2.0
# 1   590         House     Private room             3        1.0       1.0
# 2   592         House     Private room             2        1.0       1.0
# 3  1940    Guesthouse  Entire home/apt             2        1.0       0.0
# 4  2086     Apartment  Entire home/apt             2        1.0       1.0
#
#    beds
# 0   3.0
# 1   1.0
# 2   1.0
# 3   1.0
# 4   1.0

# %%
acc_filter_value = input('How many people ?:\n')
df_size_filtered = df_size[df_size['accommodates'].isin([acc_filter_value])]

df_size_filtered
# Out:
# How many people ?:
# 4
# Empty DataFrame
# Columns: [id, property_type, room_type, accommodates, bathrooms, bedrooms, beds]
# Index: []

# %%
import streamlit as st 
import pandas as pd

st.write(df_size)
df_result_search = pd.DataFrame() 


searchcheckbox_place_type = st.checkbox("Property type or room type ",value = False,key=1)
searchcheckbox_accomodates = st.checkbox("accommodates",value = False,key=2)

if searchcheckbox_place_type:
    property_type_search = st.text_input("property_type")
    room_type_search = st.text_input("room_type")
else:
    property_type_search = ''
    room_type_search = ''

if searchcheckbox_age:   
    acc_search = st.number_input("accommodates",min_value=0)
else:
    acc_search = 0

if st.button("search"):
    # 1. only property/room is checked
    if searchcheckbox_place_type and not searchcheckbox_accomodates:
        # if property is specified but not the room
        if property_type_search != '' and room_type_search == '':
            df_result_search = df_size[df_size['property_type'].str.contains(property_type_search, case=False, na=False)]
        # if room is specified but not the property
        elif name_search == '' and nickname_search != '':
            df_result_search = df_size[df_size['room_type'].str.contains(room_type_search, case=False, na=False)]
        # if both property and room are specified
        elif property_type_search != '' and room_type_search != '':
            df_result_search = df_size[(df_size['property_type'].str.contains(property_type_search, case=False, na=False)) & (df_size['room_type'].str.contains(room_type_search, case=False, na=False))]
        # if user does not enter anything
        else:
            st.warning('Please enter at least a property type or a room type')

    # 2. only accomodates is checked
    elif not searchcheckbox_place_type and searchcheckbox_accomodates:
        if acc_search != 0:
            df_result_search = df_size[df_size['accommodates'] == acc_search]
            
    # 3. if both property/room and age are checked
    else:
        pass  # continue here.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       4 st.write(df_size)
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
df_size_filtered = df_size.loc[(df_size["accommodates"] >= 4)]
df_size_filtered
# Out:
#             id property_type        room_type  accommodates  bathrooms  \
# 0          360    Guesthouse  Entire home/apt             4        1.0
# 7        56185         House  Entire home/apt             8        3.0
# 8        59631     Townhouse  Entire home/apt             4        2.5
# 14      142683         House  Entire home/apt             4        1.5
# 15      172196         House  Entire home/apt            10        4.0
# ...        ...           ...              ...           ...        ...
# 4860  40440457         House  Entire home/apt             6        2.0
# 4861  40442282     Apartment  Entire home/apt             4        2.0
# 4862  40443443     Apartment  Entire home/apt             4        2.0
# 4863  40454518     Apartment  Entire home/apt             4        2.0
# 4864  40454863     Apartment  Entire home/apt             4        2.0
#
#       bedrooms  beds
# 0          2.0   3.0
# 7          4.0   9.0
# 8          2.0   2.0
# 14         2.0   2.0
# ...

# %%
df_prices = pd.read_csv("C:\\Users\\ivano\\OneDrive\\Documents\\KEDGE\\MSC DATA\\Courses\\Python bootcamp\\Python_Airbnb_project\\Denver dataset\\Prices.csv")

df_prices
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 df_prices = pd.read_csv("C:\\Users\\ivano\\OneDrive\\Documents\\KEDGE\\MSC DATA\\Courses\\Python bootcamp\\Python_Airbnb_project\\Denver dataset\\Prices.csv")
#       3 df_prices
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
